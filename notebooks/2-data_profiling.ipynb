# %%
# %pip install ydata_profiling

# %%
from pathlib import Path
import pandas as pd
from ydata_profiling import ProfileReport

DRIVE_PATH = "/content/drive/MyDrive/UFF/Disciplinas/tratamento-incertezas"
train_file = Path(DRIVE_PATH, "train.csv")
test_file = Path(DRIVE_PATH, "test.csv")
train_new_features = Path(DRIVE_PATH, "train_new_features.csv")
test_new_features = Path(DRIVE_PATH, "test_new_features.csv")
report_file = Path(DRIVE_PATH, "train_sample_profile_report.html")
nsample = 10000000

# %%
print(f"Processando arquivo csv...")
df = pd.read_csv(train_new_features, nrows=nsample)
df.head(20)
# Out:
# Processando arquivo csv...
#     tr_id  route_changed  date_index  rtt_mean  rtt_std  rtt_range  rtt_count  \
# 0       0              0           1    210.09      0.0        0.0          1
# 1       1              0           1    210.09      0.0        0.0          1
# 2       2              0           1    210.09      0.0        0.0          1
# 3       3              0           1    210.09      0.0        0.0          1
# 4       4              0           1    210.09      0.0        0.0          1
# 5       5              0           1    210.09      0.0        0.0          1
# 6       6              0           1    210.09      0.0        0.0          1
# 7       7              0           1    210.09      0.0        0.0          1
# 8       8              0           1    210.09      0.0        0.0          1
# 9       9              0           1    210.09      0.0        0.0          1
# 10   2579              1           1    221.98      0.0        0.0          1
# 11   2580              0           1    221.98      0.0        0.0          1
# 12   2581              0           1    221.98      0.0        0.0          1
# 13   2582              0           1    221.98      0.0        0.0          1
# 14   2583              0           1    221.98      0.0        0.0          1
# 15   2584              0           1    221.98      0.0        0.0          1
# 16   2585              0           1    221.98      0.0        0.0          1
# 17   2586              0           1    221.98      0.0        0.0          1
# 18   2587              0           1    221.98      0.0        0.0          1
# 19   2588              0           1    221.98      0.0        0.0          1
#
#     time_since_last  reply_ratio  probe_efficiency  pair_id
# 0               0.0          1.0              0.33        0
# 1               0.0          1.0              0.33        0
# 2               0.0          1.0              0.33        0
# 3               0.0          1.0              0.33        0
# 4               0.0          1.0              0.33        0
# 5               0.0          1.0              0.33        0
# 6               0.0          1.0              0.33        0
# 7               0.0          1.0              0.33        0
# 8               0.0          1.0              0.33        0
# 9               0.0          1.0              0.33        0
# 10            679.0          0.5              0.33        0
# 11              0.0          0.5              0.33        0
# 12              0.0          0.5              0.33        0
# 13              0.0          0.5              0.33        0
# 14              0.0          0.5              0.33        0
# 15              0.0          0.5              0.33        0
# 16              0.0          0.5              0.33        0
# 17              0.0          0.5              0.33        0
# 18              0.0          0.5              0.33        0
# 19              0.0          0.5              0.33        0

# %%
profile = ProfileReport(df, title="Dataset Profiling Report", explorative=True)

# %%
profile.to_file(report_file)
print("Profile report generated: train_sample_profile_report.html")
# Out:
# Profile report generated: train_sample_profile_report.html
